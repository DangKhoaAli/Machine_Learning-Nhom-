# %%
from IPython import display

# %%
try:
    import nbformat
except:
    # %pip install nbformat
display.clear_output()

# %%
action = 'main_feat01' 
seed = 42 
exps_dir = '../../exps' 
exp_name = 'titanic_baseline' 
data_dir = '../../data' 
verbose = True
k_folds = 10

# %run ../models/baseline.ipynb
# Out:
# + seed: 42
# + exp_dir: d:\ML_git\Machine_Learning_basic\Titanic_final\exps\output
# + exp_name: result_baseline
# + data_dir: d:\ML_git\Machine_Learning_basic\Titanic_final\exps\feature1
# + verbose: True
# + k_fold: 10
# + save_dir: d:\ML_git\Machine_Learning_basic\Titanic_final\exps\output\result_baseline
#      PassengerId  Survived  Pclass  \
# 208          209         1       3
# 194          195         1       1
# 423          424         0       3
# 592          593         0       3
# 263          264         0       1
#
#                                                   Name     Sex       Age  \
# 208                          Carr, Miss. Helen "Ellen"  female  2.833213
# 194          Brown, Mrs. James Joseph (Margaret Tobin)  female  3.806662
# 423  Danbom, Mrs. Ernst Gilbert (Anna Sigrid Maria ...  female  3.367296
# 592                         Elsbury, Mr. William James    male  3.871201
# 263                              Harrison, Mr. William    male  3.713572
#
# ...
